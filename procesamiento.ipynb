# %% [markdown]
# # Librerias a utilizar

# %%
# librerias para manipulacion de archivos
import os
import glob

# librerias para manipulacion de imagenes
import cv2 as cv
import numpy as np

# librerias de utilidad
import hashlib

# %% [markdown]
# # Realizar primer procesamiento
# ---
# ### Eliminacion de duplicados
# La función **hash_archivo** calcula el hash MD5 del contenido de un archivo. Luego, el código recorre todos los archivos en el directorio, calculando el hash de cada archivo con las extensiones especificadas (jpg, jpeg, png, txt). Si el hash de un archivo ya existe en el diccionario hashes, se considera un duplicado y se elimina. Si el hash no existe, se agrega al diccionario.
#
# ### procesamiento de archivos de anotaciones e imagenes
# La función **process_annotations** recorre los archivos de anotaciones, buscando las correspondientes imágenes, y convierte las anotaciones al formato YOLO si es necesario. También elimina los archivos de anotaciones si no se encuentra la imagen correspondiente.
#
# La función **process_annotations** tambien utiliza:
# - La función **is_yolo_format** verifica si una línea de anotación está en el formato YOLO adecuado.
# - La función **convert_to_yolo_format** convierte las anotaciones que no están en el formato YOLO a dicho formato, calculando los valores del centro, ancho y alto de las bounding boxes a partir de las coordenadas de las esquinas.
#
# La función **validate_images_and_annotations** verifica que cada imagen tenga su archivo de anotación y viceversa, eliminando cualquier archivo huérfano que no tenga su correspondiente par.

# %% [markdown]
# ### **NOTA**: las imagenes deben descargarse manualmente desde el siguiente link:
#
# *https://drive.google.com/drive/folders/1Ad7wlGabhY_QiTxzWQBVxbz0E8PqmUoK?usp=drive_link*
#
# ### Una vez descargadas solo se debe mover a la carpeta dentro de la carpeta truco_app y ejecutar las celdas que siguen.

# %%
# Ruta a la carpeta que contiene las imágenes y archivos .txt
DATA_PATH = "./fotos_textos_data"

# %% [markdown]
# ### Eliminacion de duplicados

# %%
def hash_archivo(file_path):
    """Calcula el hash MD5 del contenido de un archivo."""
    hasher = hashlib.md5()
    with open(file_path, 'rb') as afile:
        buf = afile.read()
        hasher.update(buf)
    return hasher.hexdigest()

# Diccionario para almacenar hashes y sus rutas de archivo correspondientes
hashes = {}

# Recorrer todos los archivos en el directorio
for root, dirs, files in os.walk(DATA_PATH):
    for file in files:
        if file.endswith(('.jpg', '.jpeg', '.png', '.txt')):  # Filtra por extensiones deseadas
            ruta_completa_archivo = os.path.join(root, file)
            archivo_hash = hash_archivo(ruta_completa_archivo)
            
            if archivo_hash in hashes:
                # Si el hash ya existe, eliminar el archivo duplicado
                print(f'Eliminando duplicado: {ruta_completa_archivo}')
                os.remove(ruta_completa_archivo)
            else:
                # Si el hash no existe, agregarlo al diccionario
                hashes[archivo_hash] = ruta_completa_archivo

print("Eliminación de duplicados completada.")
# Out:
# Eliminación de duplicados completada.

# %% [markdown]
# ### procesamiento de archivos.txt e imagenes

# %%
def is_yolo_format(line):
    parts = line.strip().split()
    if len(parts) == 5:
        try:
            int(parts[0])
            [float(coord) for coord in parts[1:]]
            return True
        except ValueError:
            return False
    return False

def convert_to_yolo_format(annotation_lines, image_w, image_h):
    yolo_lines = []
    for line in annotation_lines:
        parts = line.strip().split()
        if len(parts) > 5:
            class_id = parts[0]
            points = [float(p) for p in parts[1:]]
            points = np.array(points).reshape(-1, 2)
            
            x_min = np.min(points[:, 0]) * image_w
            y_min = np.min(points[:, 1]) * image_h
            x_max = np.max(points[:, 0]) * image_w
            y_max = np.max(points[:, 1]) * image_h

            x_center = (x_min + x_max) / 2 / image_w
            y_center = (y_min + y_max) / 2 / image_h
            width = (x_max - x_min) / image_w
            height = (y_max - y_min) / image_h

            yolo_line = f"{class_id} {x_center} {y_center} {width} {height}\n"
        else:
            yolo_line = line

        yolo_lines.append(yolo_line)
    return yolo_lines

def process_annotations(data_path):
    label_files = glob.glob(f"{data_path}/*.txt")

    for label_file in label_files:
        base_name = os.path.basename(label_file).split(".")[0]
        image_path = None

        for ext in ["jpg", "png", "jpeg"]:
            possible_path = os.path.join(data_path, f"{base_name}.{ext}")
            if os.path.exists(possible_path):
                image_path = possible_path
                break

        if not image_path:
            print(f"Imagen no encontrada para {label_file}, eliminando {label_file}")
            os.remove(label_file)
            continue

        image = cv.imread(image_path)
        if image is None:
            print(f"No se pudo leer la imagen: {image_path}, eliminando {label_file}")
            os.remove(label_file)
            continue

        image_h, image_w, _ = image.shape

        with open(label_file, "r") as file:
            lines = file.readlines()

        yolo_lines = []
        for line in lines:
            if is_yolo_format(line):
                yolo_lines.append(line)
            else:
                yolo_lines.extend(convert_to_yolo_format([line], image_w, image_h))

        with open(label_file, "w") as file:
            file.writelines(yolo_lines)

        print(f"Procesado {label_file} - Transformación aplicada correctamente")

def validate_images_and_annotations(data_path):
    image_files = []
    for ext in ["jpg", "png", "jpeg"]:
        image_files.extend(glob.glob(f"{data_path}/*.{ext}"))

    label_files = glob.glob(f"{data_path}/*.txt")

    image_basenames = {os.path.splitext(os.path.basename(f))[0] for f in image_files}
    label_basenames = {os.path.splitext(os.path.basename(f))[0] for f in label_files}

    images_without_labels = image_basenames - label_basenames
    labels_without_images = label_basenames - image_basenames

    for basename in images_without_labels:
        for ext in ["jpg", "png", "jpeg"]:
            image_path = os.path.join(data_path, f"{basename}.{ext}")
            if os.path.exists(image_path):
                print(f"Eliminando imagen sin etiqueta: {image_path}")
                os.remove(image_path)

    for basename in labels_without_images:
        label_path = os.path.join(data_path, f"{basename}.txt")
        if os.path.exists(label_path):
            print(f"Eliminando etiqueta sin imagen: {label_path}")
            os.remove(label_path)

# %%
# Primero validar imágenes y anotaciones
validate_images_and_annotations(DATA_PATH)

# Procesar imagenes y anotaciones
process_annotations(DATA_PATH)
# Out:
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_04.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_29.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_30.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_13.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_18.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_23.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_10.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_03.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_25.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_24.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_09.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_22.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_28.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_08.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_16.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_12.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_17.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_02.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_19.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_27.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_11.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_06.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_05.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_07.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_14.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_01.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_21.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_15.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_26.jpg
# Eliminando imagen sin etiqueta: ./fotos_textos_data\43265_Lucas_Demarré_20.jpg
# Procesado ./fotos_textos_data\070d392d14a7cea469fee82f0754a289.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\0a1343bac8cb2b14b120bc01bff80676.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\0d4a74a58600d4a06f3738e853d315bb.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\0fb5c9753bb52557372074f5f39c4a3d.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\10d2680f1d5794a1f9eb029351d4d59f.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\114a4ab5c3363398cd16a4df0aea9cdb.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\12394_escandell_ariel_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\17211af4d041d345cb72fbf6dd0417ba.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\2321cd43cc466e7f778598d05b07889c.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\23451_guido_lorenzettibruera_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\277a4b435b871683e37e45daca19c4f6.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\293cf3fc96a4dbd5d6004436ddc39b48.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\2daf52b1e418b7b095b9d2736bd32848.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\32bec048e26960e538b64386d2117184.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\32d8cd3cc1799c7e150bade5617735ce.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\33219c585c5dac63340294dda6e34412.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\3326205021f38e32701b096ffa2e8782.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\33db56c3f1d54e81049c8f576f8c5a15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\36634323f7c586d8ad3802ed00241142.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37020de3e892d3111d714b931b2f4fce.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37249_fontela_facundo_32.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\372d73de811a362dc90c3d847788439f.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37494_gustavo_fontana_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\37524_augusto_farias_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\3a32cc04e4d840bc441431183e08d018.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\3cbb052c7f4127313a34629e22f95f52.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\3def1af971fef00145004195550cf81b.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\3f3888c76dfcd3176d832be7c9d7ac23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_0.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_1.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_2.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_3.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_4.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_5.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_6.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_7.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_8.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\41932688_Simon_Revello_9.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\423654a8d7575c56e7d495effa12d6f7.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_0.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_1.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_2.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_3.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_32.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_33.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_34.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_35.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_36.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_4.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_6.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_7.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43237686_Constantino_Ferrucci_9.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (1).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (10).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (11).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (12).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (13).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (14).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (15).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (16).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (17).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (18).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (19).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (2).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (20).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (21).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (22).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (23).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (24).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (25).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (26).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (27).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (28).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (29).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (3).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (30).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (31).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (32).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (33).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (34).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (35).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (36).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (37).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (38).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (39).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (4).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (40).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (41).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (42).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (43).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (44).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (45).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (46).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (47).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (48).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (49).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (5).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (50).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (6).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (7).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (8).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43491353_Alejo_Lo_Menzo (9).txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_00.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_32.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_34.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_35.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_36.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_37.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_38.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43841031_Enzo_Ferrari_39.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\43c3857f9e3cb75cefd4cb7db3cba75f.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\444067f9638cc7732f454f076cf67609.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\44df7290b1c1505ad03ef87942ca0468.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\45d7f692f3ad5a74191f2b002c00f796.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_32.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_35.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_36.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46019_taiel_raffaeli_37.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_1.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_2.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_3.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_32.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_4.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_5.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_6.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_7.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_8.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\46094_Mateo_Rovere_9.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\49cf91ad867c2d81a1eef82ebba7c4ee.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\49ec2ac308d5afa8cf63345cc8267d65.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\4a4de39dd9e1262c95229baccafd848b.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51659_antonio_peroni_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51705_micaela_pozzo_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\517424daa31aef6c50af72ceff7b3b92.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\51934_pablo_pistelli_01.txt - Transformación aplicada correctamente
# ...
# Procesado ./fotos_textos_data\R-45489_sofiarondini_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_32.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_33.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_34.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45489_sofiarondini_35.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\R-45829_Abril_Rodriguez_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_0.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_1.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_2.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_3.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_32.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_33.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_34.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_35.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_36.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_37.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_38.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_39.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_4.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_40.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_41.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_42.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_43.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_44.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_45.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_46.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_47.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_48.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_49.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_5.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_6.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_7.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_8.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56189_salvador_sanchez_9.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\s56804_alexis_segui_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_01.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_02.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_03.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_04.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_05.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_06.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_07.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_08.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_09.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_10.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_11.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_12.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_13.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_14.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_15.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_16.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_17.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_18.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_19.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_20.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_21.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_22.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_23.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_24.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_25.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_26.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_27.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_28.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_29.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_30.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_31.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_32.txt - Transformación aplicada correctamente
# Procesado ./fotos_textos_data\w05576_juan_wagner_33.txt - Transformación aplicada correctamente
